# %% [markdown]
# # Time-Series Forecasting of Avocado Prices using FBProphet

# %% [markdown]
# # Problem Statement

# %% [markdown]
# - Data represents weekly 2018 retail scan data for National retail volume (units) and price.
# - Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
# - The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
# - The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# - Date - The date of the observation
# - AveragePrice - the average price of a single avocado
# - type - conventional or organic
# - year - the year
# - Region - the city or region of the observation
# - Total Volume - Total number of avocados sold
# - 4046 - Total number of avocados with PLU 4046 sold
# - 4225 - Total number of avocados with PLU 4225 sold
# - 4770 - Total number of avocados with PLU 4770 sold

# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random
import seaborn as sns
from fbprophet import Prophet

# %%
# dataframes creation for both training and testing datasets 
avocado_df = pd.read_csv('avocado.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Let's view the dataset
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
avocado_df["Date"] = pd.to_datetime(avocado_df["Date"])

# %%
avocado_df = avocado_df.sort_values("Date")
avocado_df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569          51 2015-01-04          1.75      27365.89     9307.34
# 9593           51 2015-01-04          1.49      17723.17     1189.35
# 10009          51 2015-01-04          1.68       2896.72      161.68
# 1819           51 2015-01-04          1.52      54956.80     3013.04
# 9333           51 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574            0 2018-03-25          1.36     908202.13   142681.06
# 9018            0 2018-03-25          0.70    9010588.32  3999735.71
# 18141           0 2018-03-25          1.42     163496.70    29253.30
# 17673           0 2018-03-25          1.70     190257.38    29644.09
# 8814            0 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 11569    3844.81     615.28    13598.46    13061.10      537.36         0.00
# 9593    15628.27       0.00      905.55      905.55        0.00         0.00
# 10009     206.96       0.00     2528.08     2528.08        0.00         0.00
# 1819    35456.88    1561.70    14925.18    11264.80     3660.38         0.00
# 9333     1129.50       0.00      374.35      186.67      187.68         0.00
# ...          ...        ...         ...         ...         ...          ...
# 8574   463136.28  174975.75   127409.04   103579.41    22467.04      1362.59
# 9018   966589.50   30130.82  4014132.29  3398569.92   546409.74     69152.63
# 18141    5080.04       0.00   129163.36   109052.26    20111.10         0.00
# 17673   70982.10       0.00    89631.19    89424.11      207.08         0.00
# 8814   908653.71     843.45   801373.63   774634.09    23833.93      2905.61
#
#                type  year              region
# 11569       organic  2015           Southeast
# 9593        organic  2015             Chicago
# 10009       organic  2015  HarrisburgScranton
# 1819   conventional  2015          Pittsburgh
# 9333        organic  2015               Boise
# ...             ...   ...                 ...
# 8574   conventional  2018             Chicago
# 9018   conventional  2018        SouthCentral
# 18141       organic  2018        SouthCentral
# 17673       organic  2018          California
# 8814   conventional  2018             NewYork
#
# [18249 rows x 14 columns]

# %%
plt.figure(figsize=(14,6))
plt.scatter(x=avocado_df['Date'], y=avocado_df['AveragePrice'])

# %%
# Use seaborn line plot with mean and standard deviation errors to see it better
plt.figure(figsize=(14,6))
sns.lineplot(x="Date", y="AveragePrice", data=avocado_df, ci="sd")

# %%
# Count number of regions 
avocado_df['region'].value_counts()
# Out:
# Northeast              338
# Boston                 338
# Spokane                338
# Louisville             338
# BuffaloRochester       338
# West                   338
# Tampa                  338
# Houston                338
# Chicago                338
# Syracuse               338
# Philadelphia           338
# Plains                 338
# Albany                 338
# PhoenixTucson          338
# Orlando                338
# Columbus               338
# CincinnatiDayton       338
# Indianapolis           338
# NewOrleansMobile       338
# Denver                 338
# HarrisburgScranton     338
# NorthernNewEngland     338
# Pittsburgh             338
# RaleighGreensboro      338
# Portland               338
# Roanoke                338
# BaltimoreWashington    338
# HartfordSpringfield    338
# TotalUS                338
# Midsouth               338
# Atlanta                338
# LasVegas               338
# Seattle                338
# SanDiego               338
# Boise                  338
# Nashville              338
# California             338
# Detroit                338
# Charlotte              338
# GrandRapids            338
# SouthCarolina          338
# GreatLakes             338
# RichmondNorfolk        338
# SanFrancisco           338
# LosAngeles             338
# Jacksonville           338
# Sacramento             338
# MiamiFtLauderdale      338
# SouthCentral           338
# Southeast              338
# DallasFtWorth          338
# StLouis                338
# NewYork                338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
print('Unique Regions:', len(avocado_df['region'].unique()))
avocado_df['region'].unique()
# Out:
# Unique Regions: 54
# array(['Southeast', 'Chicago', 'HarrisburgScranton', 'Pittsburgh',
#        'Boise', 'WestTexNewMexico', 'LosAngeles', 'LasVegas', 'Atlanta',
#        'DallasFtWorth', 'MiamiFtLauderdale', 'Plains', 'StLouis',
#        'Syracuse', 'Midsouth', 'Sacramento', 'Boston', 'Charlotte',
#        'Spokane', 'Albany', 'Houston', 'SouthCarolina', 'SanFrancisco',
#        'TotalUS', 'RaleighGreensboro', 'BuffaloRochester',
#        'NorthernNewEngland', 'GrandRapids', 'Denver', 'SanDiego',
#        'BaltimoreWashington', 'Roanoke', 'RichmondNorfolk', 'Northeast',
#        'SouthCentral', 'GreatLakes', 'Louisville', 'Seattle',
#        'CincinnatiDayton', 'NewYork', 'NewOrleansMobile', 'Indianapolis',
#        'Jacksonville', 'Columbus', 'Detroit', 'Philadelphia',
#        'PhoenixTucson', 'Nashville', 'Portland', 'HartfordSpringfield',
#        'Tampa', 'Orlando', 'West', 'California'], dtype=object)

# %%
# Count number of years 
avocado_df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
# Count number of types 
avocado_df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
# Check for missing data
avocado_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
plt.figure(figsize=(14,6))
plt.scatter(avocado_df['Date'][avocado_df['type']=='conventional'], avocado_df['AveragePrice'][avocado_df['type']=='conventional'],alpha=0.25)
plt.scatter(avocado_df['Date'][avocado_df['type']=='organic'], avocado_df['AveragePrice'][avocado_df['type']=='organic'],alpha=0.25)
plt.legend(['Conventional','Organic'])

# %%
# Use seaborn line plot with mean and standard deviation errors to see it better
plt.figure(figsize=(14,6))
sns.lineplot(x="Date", y="AveragePrice", data=avocado_df[avocado_df['type']=='conventional'], ci="sd")
sns.lineplot(x="Date", y="AveragePrice", data=avocado_df[avocado_df['type']=='organic'], ci="sd")
plt.legend(['Conventional','Organic'])

# %% [markdown]
# It seems like Organic avocados are more expensive than Conventional avocados. However, they both follow a similar seasonality pattern each year, where the prices peak towards the end of the year, and bottom in the beginning of the year.

# %%
avocado_conv = avocado_df[['Date', 'AveragePrice']][avocado_df['type']=='conventional']
avocado_org = avocado_df[['Date', 'AveragePrice']][avocado_df['type']=='organic']

# %%
avocado_org
# Out:
#             Date  AveragePrice
# 11569 2015-01-04          1.75
# 9593  2015-01-04          1.49
# 10009 2015-01-04          1.68
# 9333  2015-01-04          1.64
# 10269 2015-01-04          1.50
# ...          ...           ...
# 17841 2018-03-25          1.75
# 18057 2018-03-25          1.42
# 17649 2018-03-25          1.74
# 18141 2018-03-25          1.42
# 17673 2018-03-25          1.70
#
# [9123 rows x 2 columns]

# %%
# Explore price distrubution of the all avocados or only conventional or only organic
f, axes = plt.subplots(1, 3, figsize=(15, 4), sharex=True)
sns.distplot(avocado_df["AveragePrice"], color = 'r', ax=axes[0])
axes[0].set_title('Distribution of all Price')

sns.distplot(avocado_conv["AveragePrice"], color = 'b', ax=axes[1])
axes[1].set_title('Distribution of Conventional Price')

sns.distplot(avocado_org["AveragePrice"], color = 'g', ax=axes[2])
axes[2].set_title('Distribution of Organic Price')
plt.tight_layout()

# %%
sns.boxplot(y="type", x="AveragePrice", data=avocado_df)

# %%
# Check Organic Prices by region
mask = avocado_df['type']=='organic'
g = sns.catplot('AveragePrice','region',data=avocado_df[mask],
                hue='year',
                height=13,
                aspect=0.8,
                palette='magma',
                kind="point",
                join=False
              )
plt.subplots_adjust(top=0.95)
g.fig.suptitle('Organic Prices by region')
# Out:
# Text(0.5, 0.98, 'Organic Prices by region')

# %%
# Check Conventional Prices by region
mask = avocado_df['type']=='conventional'
g = sns.catplot('AveragePrice','region',data=avocado_df[mask],
                hue='year',
                height=13,
                aspect=0.8,
                palette='magma',
                kind="point",
                join=False
              )
plt.subplots_adjust(top=0.95)
g.fig.suptitle('Conventional Prices by region')
# Out:
# Text(0.5, 0.98, 'Conventional Prices by region')

# %%
# plot volume
monthly = avocado_df[avocado_df['type']=='conventional'].set_index("Date")
monthly = monthly.resample('M').sum()
monthly["mean"] = monthly["Total Volume"].rolling(6).mean()
sns.lineplot(x=monthly.index,y=monthly["Total Volume"], color="b")
sns.lineplot(x=monthly.index,y=monthly["mean"], color="r")
plt.legend(["Volume","Moving Average (6)"])

# %% [markdown]
# # Forecast

# %%
avocado_conv = avocado_conv.rename(columns={'Date':'ds', 'AveragePrice':'y'})
avocado_org  = avocado_org.rename(columns={'Date':'ds', 'AveragePrice':'y'})

# %%
avocado_org
# Out:
#               ds     y
# 11569 2015-01-04  1.75
# 9593  2015-01-04  1.49
# 10009 2015-01-04  1.68
# 9333  2015-01-04  1.64
# 10269 2015-01-04  1.50
# ...          ...   ...
# 17841 2018-03-25  1.75
# 18057 2018-03-25  1.42
# 17649 2018-03-25  1.74
# 18141 2018-03-25  1.42
# 17673 2018-03-25  1.70
#
# [9123 rows x 2 columns]

# %%
m_conv = Prophet()
m_org = Prophet()
m_conv.fit(avocado_conv)
m_org.fit(avocado_org)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Forcasting into the future
future_conv = m_conv.make_future_dataframe(periods=365)
future_org = m_org.make_future_dataframe(periods=365)
forecast_conv = m_conv.predict(future_conv)
forecast_org = m_org.predict(future_org)

# %%
forecast_conv
# Out:
#              ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0    2015-01-04  1.221983    0.839922    1.389181     1.221983     1.221983
# 1    2015-01-04  1.221983    0.840132    1.371924     1.221983     1.221983
# 2    2015-01-04  1.221983    0.841073    1.385269     1.221983     1.221983
# 3    2015-01-04  1.221983    0.834847    1.373329     1.221983     1.221983
# 4    2015-01-04  1.221983    0.837291    1.367242     1.221983     1.221983
# ...         ...       ...         ...         ...          ...          ...
# 9486 2019-03-21  0.910078    0.453768    1.272617     0.612128     1.198395
# 9487 2019-03-22  0.909292    0.442466    1.273310     0.610001     1.199444
# 9488 2019-03-23  0.908506    0.448197    1.268564     0.607875     1.200462
# 9489 2019-03-24  0.907720    0.420833    1.291152     0.605748     1.201080
# 9490 2019-03-25  0.906933    0.469327    1.259604     0.603621     1.201508
#
#       additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0          -0.113787             -0.113787             -0.113787 -0.113787
# 1          -0.113787             -0.113787             -0.113787 -0.113787
# 2          -0.113787             -0.113787             -0.113787 -0.113787
# 3          -0.113787             -0.113787             -0.113787 -0.113787
# 4          -0.113787             -0.113787             -0.113787 -0.113787
# ...              ...                   ...                   ...       ...
# 9486       -0.048837             -0.048837             -0.048837 -0.048837
# 9487       -0.047348             -0.047348             -0.047348 -0.047348
# 9488       -0.045442             -0.045442             -0.045442 -0.045442
# 9489       -0.043144             -0.043144             -0.043144 -0.043144
# 9490       -0.040494             -0.040494             -0.040494 -0.040494
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 0        -0.113787     -0.113787                   0.0
# 1        -0.113787     -0.113787                   0.0
# 2        -0.113787     -0.113787                   0.0
# 3        -0.113787     -0.113787                   0.0
# 4        -0.113787     -0.113787                   0.0
# ...            ...           ...                   ...
# 9486     -0.048837     -0.048837                   0.0
# 9487     -0.047348     -0.047348                   0.0
# 9488     -0.045442     -0.045442                   0.0
# 9489     -0.043144     -0.043144                   0.0
# 9490     -0.040494     -0.040494                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                            0.0                         0.0  1.108197
# 1                            0.0                         0.0  1.108197
# 2                            0.0                         0.0  1.108197
# 3                            0.0                         0.0  1.108197
# 4                            0.0                         0.0  1.108197
# ...                          ...                         ...       ...
# 9486                         0.0                         0.0  0.861241
# 9487                         0.0                         0.0  0.861944
# 9488                         0.0                         0.0  0.863064
# 9489                         0.0                         0.0  0.864575
# 9490                         0.0                         0.0  0.866439
#
# [9491 rows x 16 columns]

# %%
figure_conv = m_conv.plot(forecast_conv, xlabel='Date', ylabel='Price',figsize=(14,6))
figure_conv2 = m_conv.plot_components(forecast_conv)

# %%
figure_org = m_org.plot(forecast_org, xlabel='Date', ylabel='Price',figsize=(14,6))
figure_org2 = m_org.plot_components(forecast_org)

# %% [markdown]
# # Try Predicting for only one region

# %%
avocado_df_sample = avocado_df[avocado_df['region']=='West']
# avocado_df_sample = avocado_df_sample.sort_values("Date")

# %%
avocado_sample_conv = avocado_df_sample[['Date', 'AveragePrice']][avocado_df_sample['type']=='conventional']
avocado_sample_org = avocado_df_sample[['Date', 'AveragePrice']][avocado_df_sample['type']=='organic']

# %%
plt.figure(figsize=(14,6))
plt.plot(avocado_sample_conv['Date'], avocado_sample_conv['AveragePrice'])
plt.plot(avocado_sample_org['Date'], avocado_sample_org['AveragePrice'])

# %%
avocado_sample_conv = avocado_sample_conv.rename(columns={'Date':'ds', 'AveragePrice':'y'})
avocado_sample_org = avocado_sample_org.rename(columns={'Date':'ds', 'AveragePrice':'y'})

# %%
m_conv = Prophet()
m_org = Prophet()
m_conv.fit(avocado_sample_conv)
m_org.fit(avocado_sample_org)
# Forcasting into the future
future_conv = m_conv.make_future_dataframe(periods=365)
future_org = m_org.make_future_dataframe(periods=365)
forecast_conv = m_conv.predict(future_conv)
forecast_org = m_org.predict(future_org)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
figure_conv = m_conv.plot(forecast_conv, xlabel='Date', ylabel='Price',figsize=(14,6))
figure_conv2 = m_conv.plot_components(forecast_conv)

# %%
figure_org = m_org.plot(forecast_org, xlabel='Date', ylabel='Price',figsize=(14,6))
figure_org2 = m_org.plot_components(forecast_org)

# %% [markdown]
# # The End!
